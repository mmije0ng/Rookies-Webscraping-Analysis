# %% [markdown]
# 루키즈 개발 5기 박미정
#
# # Daum 뉴스 스크래핑 실습
# ## 1. 웹스크래핑 연습문제

# %% [markdown]
# ## 1-1. Daum 뉴스기사 제목 스크래핑하기
# ###  질문1 :  아래의 url에서 뉴스기사의 링크와 제목을 출력하세요.

# %%
import requests
from bs4 import BeautifulSoup

# %%
import requests
from bs4 import BeautifulSoup

# 다음 경제 뉴스 URL
url = 'https://news.daum.net/economy'

# 요청
response = requests.get(url)
response.encoding = 'utf-8'

# 실행결과 출력 요구사항
print(url)
print(type(response))
print(response.status_code)
# Out:
# https://news.daum.net/economy
# <class 'requests.models.Response'>
# 200

# %%
if response.status_code == 200:
    # BeautifulSoup 객체 생성
    soup = BeautifulSoup(response.text, 'html.parser')

    # 뉴스 리스트 선택
    li_tags = soup.select('ul.list_newsheadline2 li')
    print(type(li_tags), len(li_tags))

    # 뉴스 링크 + 제목 출력
    for li_tag in li_tags:
        a_tag = li_tag.find('a')
        strong_tag = li_tag.select_one('div.cont_thumb strong.tit_txt')

        if a_tag and strong_tag:
            link = a_tag['href']
            title = strong_tag.text.strip()

            print(link)
            print(title)

else:
    print(f'Error Code = {response.status_code}')
# Out:
# <class 'bs4.element.ResultSet'> 9
# https://v.daum.net/v/20260206134044330
# 경상수지 역대급 흑자 냈지만…달러, 해외로 ‘줄줄’
# https://v.daum.net/v/20260206130608463
# [박선영의 금융 디파인(DeFine) <23>] 원·달러 환율은 왜 정책 논쟁이 아닌 '신념의 대상'이 됐는가
# https://v.daum.net/v/20260206130604461
# [성광호의 세무 ABC <7>] 강남 55억원 아파트, 준비 없으면 상속세 17억… 반으로 줄이려면
# https://v.daum.net/v/20260206130428406
# [뉴스나우] 서울 아파트값 숨 고르기...정부, 부동산 압박 효과 있나?
# https://v.daum.net/v/20260206124318013
# 선거용인가 진심인가… 국힘·서울시 '재초환 폐지론' 왜 꺼냈나
# https://v.daum.net/v/20260206120731304
# '똘똘한 한 채' 막을 확실한 방법...이 대통령을 응원합니다
# https://v.daum.net/v/20260206114909631
# "정수기엔 수돗물만 넣으세요" 휴대용 정수기 품질·안전 평가
# https://v.daum.net/v/20260206114908629
# "지금 사라면서요?" 금 전문가 "이 가격이면 100톤 살게요!"
# https://v.daum.net/v/20260206112702703
# 부동산과 정치 [취재파일]

# %% [markdown]
# ## 질문 2. 여러개의 section 중 하나를 선택해서 url에서 뉴스기사의 링크와 제목을 출력하는 코드를 함수로 작성하기

# %%
import requests
from bs4 import BeautifulSoup

# %%
section_dict = {
    '기후/환경': 'climate',
    '사회': 'society',
    '경제': 'economy',
    '정치': 'politics',
    '국제': 'world',
    '문화': 'culture',
    '생활': 'life',
    'IT/과학': 'tech',
    '인물': 'people'
}

# 전달받은 섹션 이름에 해당하는 다음 뉴스 제목과 링크를 출력하는 함수
def print_news(section_name):
    # 한글 섹션명을 기준으로 실제 URL에 사용되는 섹션 코드 조회
    section = section_dict.get(section_name)

    if section is None:
        print('존재하지 않는 섹션입니다.')
        return

    url = f'https://news.daum.net/{section}'

    response = requests.get(url)
    response.encoding = 'utf-8'

    # 현재 조회 중인 뉴스 섹션 정보 출력
    print(f'======> {url} {section_name} 뉴스 <======')

    # 요청이 정상적으로 처리된 경우
    if response.status_code == 200:
        # HTML 문서를 BeautifulSoup 객체로 파싱
        soup = BeautifulSoup(response.text, 'html.parser')

        # 뉴스 헤드라인 목록이 포함된 li 태그 전체 선택
        li_tags = soup.select('ul.list_newsheadline2 li')

        # 각 뉴스 항목에 대해 반복 처리
        for li_tag in li_tags:
            # 뉴스 상세 페이지로 이동하는 a 태그 선택
            a_tag = li_tag.find('a')

            # 뉴스 제목이 포함된 strong 태그 선택
            strong_tag = li_tag.select_one('div.cont_thumb strong.tit_txt')

            # 링크와 제목 태그가 모두 존재할 경우만 처리
            if a_tag and strong_tag:
                # 뉴스 기사 링크 추출
                link = a_tag['href']

                # 뉴스 제목 텍스트 추출 및 공백 제거
                title = strong_tag.text.strip()

                print(link)
                print(title)
    else:
        print(f'Error Code = {response.status_code}')

# %%
print_news('사회')
# Out:
# ======> https://news.daum.net/society 사회 뉴스 <======
# https://v.daum.net/v/20260206164013919
# 北 로동신문 읽어봤더니…'김정은'은 글자부터 달랐다
# https://v.daum.net/v/20260206163931889
# [여담야담] 승부수 던지고 제주 간 장동혁…잘한다 27% 잘 못한다 56%
# https://v.daum.net/v/20260206163006403
# 대기업 채용 확대 소식에 대구경북 취업준비생 “기대감 높아요”
# https://v.daum.net/v/20260206162718298
# [여담야담] 루비오 "미 내부 분위기 좋지 않아"…통상 갈등 안보에도 불똥?
# https://v.daum.net/v/20260206161647969
# 박진경 대령 국가유공자 논란의 핵심 “가해자 연구의 부재”
# https://v.daum.net/v/20260206161224825
# "살인미수도 유죄"…생일상 차린 子 사제총 쏜 60대 끔찍 그 순간
# https://v.daum.net/v/20260206160905706
# [속보] '50억 퇴직금' 곽상도 공소기각… "잃어버린 명예 어떻게 보상 받아야 될지"
# https://v.daum.net/v/20260206160125378
# 45개 한국전쟁 유족 대표들 “진화위 담당소위, 전원 전문가로 구성하라”
# https://v.daum.net/v/20260206155132955
# ‘선거연령 16살 하향’ 찬성 많지만…학교 선거교육 수업은 ‘준비 부족’

# %%
print_news('정치')
# Out:
# ======> https://news.daum.net/politics 정치 뉴스 <======
# https://v.daum.net/v/20260206134628505
# [단독] 캄보디아 항의에 ‘K-방산’ 태국 수출 보류 위기
# https://v.daum.net/v/20260206134204370
# “이대로 가면 지방선거 필패”…장동혁 재신임 놓고 국힘 ‘와글와글’
# https://v.daum.net/v/20260206132700909
# 합당 논란에 ‘경청 행보’ 이어가는 정청래…당내 반발 잡힐까
# https://v.daum.net/v/20260206131614668
# 정청래, 합당 문건 유출 "엄정 조사"…조승래 "작성은 내 지시"(종합)
# https://v.daum.net/v/20260206130547448
# 윤재옥 "대구 경제 살리는 시장 될 것…신공항·달빛철도 신속 추진"
# https://v.daum.net/v/20260206130142326
# 왜 지금 합당인가…‘이재명 모델’로 대권 플랜 시동 건 정청래 [박동원의 시시비비]
# https://v.daum.net/v/20260206130025288
# 尹 '김영선 해줘라' 했는데…명태균 무죄 논리 뜯어보니
# https://v.daum.net/v/20260206125303173
# 막 내린 부산시의회 임시회, 본격 선거 모드 전환 관측
# https://v.daum.net/v/20260206125226161
# 이언주 "합당은 지방선거 필망 카드…반대 여론 훨씬 높아"
# https://v.daum.net/v/20260206065858953
# 윤석열이 부분이라면 전체는 무엇인가 [김영민의 연재할 결심]
# https://v.daum.net/v/20260205183345128
# [단독] 尹 측 “국무회의 심의권, 조력에 불과… 보호할 가치 없어” 주장
# https://v.daum.net/v/20260205180637049
# 전두환 면했던 '사형', 尹도 피할까? 감경사유 인정 여부가 변수
# https://v.daum.net/v/20260131110123340
# 정보사와 대학원생, 그리고 윤석열… 무인기 사건 중간 정리
# https://v.daum.net/v/20260131070214336
# 순직한 전 총리, 실형 받은 전 대통령 부인, 제명된 전 대표… [신문 1면 사진들]

# %%
print_news('경제')
# Out:
# ======> https://news.daum.net/economy 경제 뉴스 <======
# https://v.daum.net/v/20260206134044330
# 경상수지 역대급 흑자 냈지만…달러, 해외로 ‘줄줄’
# https://v.daum.net/v/20260206130608463
# [박선영의 금융 디파인(DeFine) <23>] 원·달러 환율은 왜 정책 논쟁이 아닌 '신념의 대상'이 됐는가
# https://v.daum.net/v/20260206130604461
# [성광호의 세무 ABC <7>] 강남 55억원 아파트, 준비 없으면 상속세 17억… 반으로 줄이려면
# https://v.daum.net/v/20260206130428406
# [뉴스나우] 서울 아파트값 숨 고르기...정부, 부동산 압박 효과 있나?
# https://v.daum.net/v/20260206124318013
# 선거용인가 진심인가… 국힘·서울시 '재초환 폐지론' 왜 꺼냈나
# https://v.daum.net/v/20260206120731304
# '똘똘한 한 채' 막을 확실한 방법...이 대통령을 응원합니다
# https://v.daum.net/v/20260206114909631
# "정수기엔 수돗물만 넣으세요" 휴대용 정수기 품질·안전 평가
# https://v.daum.net/v/20260206114908629
# "지금 사라면서요?" 금 전문가 "이 가격이면 100톤 살게요!"
# https://v.daum.net/v/20260206112702703
# 부동산과 정치 [취재파일]
