# %% [markdown]
# ## 1. 뉴스제목 가져오기
# * user-agent 요청헤더를 반드시 설정해야 한다.

# %%
# requests 라이브러리 설치여부 확
# !pip show requests
# Out:
# Name: requests
# Version: 2.32.5
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: C:\Users\user\anaconda3\Lib\site-packages
# Requires: certifi, charset_normalizer, idna, urllib3
# Required-by: anaconda-auth, anaconda-catalogs, anaconda-client, anaconda-project, conda, conda-build, conda-libmamba-solver, conda-repo-cli, conda_package_streaming, cookiecutter, datashader, jupyterlab_server, panel, PyGithub, requests-file, requests-toolbelt, Sphinx, streamlit, tldextract

# %%
# beautifulsoup4 라이브러리 설치여부 확인
# !pip show beautifulsoup4
# Out:
# Name: beautifulsoup4
# Version: 4.13.5
# Summary: Screen-scraping library
# Home-page: https://www.crummy.com/software/BeautifulSoup/bs4/
# Author:
# Author-email: Leonard Richardson <leonardr@segfault.org>
# License: MIT License
# Location: C:\Users\user\anaconda3\Lib\site-packages
# Requires: soupsieve, typing-extensions
# Required-by: conda-build, nbconvert

# %%
# requests, bs4 import
# BeautifulSoup 클래스 import

import requests
import bs4
from bs4 import BeautifulSoup

# %%
# requests, bs4 버전 확인하기
print(f'requests version: = {requests.__version__}')
print(f'bs4 version: = {bs4.__version__}')
# Out:
# requests version: = 2.32.1
# bs4 version: = 4.12.3

# %% [markdown]
# ### 1. 뉴스 제목 추출하기

# %%
# IT/과학 뉴스
# dict 타입으로 요청 파라미터 설정
req_param = {
    'sid': 105
}
# 
url = 'https://news.naver.com/section/{sid}'.format(**req_param)
print(url)

# 요청 헤더 설정 : 브라우저 정보 (사람처럼 보이게)
req_header = {
    'user-agent': 'Mozilla/5.0 (Linux; Android 8.0.0; SM-G955U Build/R16NW) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Mobile Safari/537.36'
}

# requests 의 get() 함수 호출하기 
res = requests.get(url, headers=req_header)

# 응답 (response)에서 text 추출
print(res.status_code)
print(res.ok) # boolean
print(type(res)) # <class 'requests.models.Response'>
print(type(res.ok)) # <class 'bool'>
# print(res.text)

if res.ok: # 응답(response)이 OK 이면
    soup = BeautifulSoup(res.text, 'html.parser') # BeautifulSoup 객체 생성
    print(len(soup.select("div.sa_text a[href^='https://n.news.naver.com/mnews/']")))
    
    # CSS 선택자를 사용해서 a tag 목록 가져오기
    a_tags = soup.select("div.sa_text a[href^='https://n.news.naver.com/mnews/']")
    print(type(a_tags), type(a_tags[0])) # [Tag, Tag]

    for a_tag in a_tags: # <a> 태그 리스트 순회
        title = a_tag.text.strip()
        link = a_tag['href']
        print(title, link)

else: # 응답(response)이 Error 이면 status code 출력
    print(f'Error Cod = {res.status_code}')
# Out:
# https://news.naver.com/section/105
# 200
# True
# <class 'requests.models.Response'>
# <class 'bool'>
# 88
# <class 'bs4.element.ResultSet'> <class 'bs4.element.Tag'>
# 넷마블, 작년 매출 2.8조 '사상 최대'…영업이익도 63.5% 증가 https://n.news.naver.com/mnews/article/079/0004112946
#  https://n.news.naver.com/mnews/article/comment/079/0004112946
#  https://n.news.naver.com/mnews/article/comment/011/0004587384
# [언박싱 연구실] 산소 없어도 OK! '물'로 암세포 터뜨리는 빛의 마법 https://n.news.naver.com/mnews/article/014/0005474373
#  https://n.news.naver.com/mnews/article/comment/014/0005474373
# 영업익 40% 줄었는데 주가는 천장…SK텔레콤의 '반전' 이유 [테크로그] https://n.news.naver.com/mnews/article/015/0005247675
#  https://n.news.naver.com/mnews/article/comment/015/0005247675
# "바빠서 못한다더니 870만원 주면 해준다고?"…블라인드 '퇴사자 계정삭제' 비용 논란 https://n.news.naver.com/mnews/article/277/0005717793
#  https://n.news.naver.com/mnews/article/comment/277/0005717793
# "55만원이래" '아이폰 에어'보다 가볍고 오래 쓰는데 가격은 3분의 1[써보니] https://n.news.naver.com/mnews/article/277/0005717794
#  https://n.news.naver.com/mnews/article/comment/277/0005717794
# 구글 “올해 AI에 270조 투자”…압도적 자본으로 경쟁자 털어내기 https://n.news.naver.com/mnews/article/009/0005633270
#  https://n.news.naver.com/mnews/article/comment/009/0005633270
# [비즈톡톡] ‘낸드플래시 컨트롤러’ 만드는 파두, AI 병목 해결사로 재평가 https://n.news.naver.com/mnews/article/366/0001140892
#  https://n.news.naver.com/mnews/article/comment/366/0001140892
# AI 단톡방 ‘몰트북’ 논란에 “애플 맥 미니 샀다” 후기 이어져 이유는? https://n.news.naver.com/mnews/article/023/0003957541
#  https://n.news.naver.com/mnews/article/comment/023/0003957541
# 주가 답보 JYP엔터… '배당 고집' 박진영, 자사주 소각은 '외면' https://n.news.naver.com/mnews/article/417/0001128543
#  https://n.news.naver.com/mnews/article/comment/417/0001128543
# 올림픽 중계권에 수백억 쏜 네이버, 치지직 특수 볼까 https://n.news.naver.com/mnews/article/003/0013752739
#  https://n.news.naver.com/mnews/article/comment/003/0013752739

# %% [markdown]
# ### 1.1 뉴스제목 추출하는 함수 선언하기

# %%
import requests
from bs4 import BeautifulSoup

section_dict = {
    '정치': 100,
    '경제': 101,
    '사회': 102,
    '생활/문화': 103,
    '세계': 104,
    'IT/과학': 105
}

def print_news(section_name):
    sid = section_dict.get(section_name, '정치')
    url = f'https://n.news.naver.com/section/{sid}'
    print(f'{section_name} 뉴스 {url}')
    
    req_header = {
    'user-agent': 'Mozilla/5.0 (Linux; Android 8.0.0; SM-G955U Build/R16NW) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Mobile Safari/537.36'
    }
    res = requests.get(url, headers=req_header)
    
    if res.ok: # 응답(response)이 OK 이면
        soup = BeautifulSoup(res.text, 'html.parser') # BeautifulSoup 객체 생성
        print(len(soup.select("div.sa_text a[href^='https://n.news.naver.com/mnews/']")))
        
        # CSS 선택자를 사용해서 a tag 목록 가져오기
        a_tags = soup.select("div.sa_text a[href^='https://n.news.naver.com/mnews/']")
        print(type(a_tags), type(a_tags[0])) # [Tag, Tag]

        for a_tag in a_tags: # <a> 태그 리스트 순회
            title = a_tag.text.strip()
            link = a_tag['href']
            print(title, link)

    else: # 응답(response)이 Error 이면 status code 출력
        print(f'Error Cod = {res.status_code}')

# %%
print_news('사회')
# Out:
# 사회 뉴스 https://n.news.naver.com/section/102
# 남양주 아파트서 함께 살던 친누나 살해 혐의 30대, 긴급체포 https://n.news.naver.com/mnews/article/031/0001003578
#  https://n.news.naver.com/mnews/article/comment/031/0001003578
# '따릉이 해킹' 알고도 2년 동안 뭉갰다…정보유출 수사 의뢰 https://n.news.naver.com/mnews/article/015/0005247819
#  https://n.news.naver.com/mnews/article/comment/015/0005247819
# 美의회, 쿠팡 소환장엔... '이재명' 실명 저격 https://n.news.naver.com/mnews/article/088/0000995785
#  https://n.news.naver.com/mnews/article/comment/088/0000995785
# "내 포르쉐로 허세 부리는 남친…친구 웨딩카로 빌려달라네요" https://n.news.naver.com/mnews/article/003/0013753252
#  https://n.news.naver.com/mnews/article/comment/003/0013753252
# "재혼 아내보다 친딸에게 더 주고 싶지만..재산 다툼할까 걱정" https://n.news.naver.com/mnews/article/018/0006214574
#  https://n.news.naver.com/mnews/article/comment/018/0006214574
# [뉴스AS]대통령이 삭제한 페북글, 대통령기록물법 위반? https://n.news.naver.com/mnews/article/028/0002790307
#  https://n.news.naver.com/mnews/article/comment/028/0002790307
# 경찰, '李대통령 비판' 칼럼니스트 불송치 결정 https://n.news.naver.com/mnews/article/014/0005474489
#  https://n.news.naver.com/mnews/article/comment/014/0005474489
# 3.9억 빚내 SK하이닉스 투자한 공무원… 강제청산 위기 넘기고 ‘수익 인증’ https://n.news.naver.com/mnews/article/366/0001140978
#  https://n.news.naver.com/mnews/article/comment/366/0001140978
# 권창영 특검 "내란 밝히지 못한 사실 많아…철저히 규명"(종합) https://n.news.naver.com/mnews/article/421/0008757737
#  https://n.news.naver.com/mnews/article/comment/421/0008757737
# 소래포구축제 만찬 식사비 대납 요구 혐의…공무원 2명 송치 https://n.news.naver.com/mnews/article/001/0015889442
#  https://n.news.naver.com/mnews/article/comment/001/0015889442
# 베트남서 아내 살해한 남편, 독사에 물려 의식 잃은 채 발견 https://n.news.naver.com/mnews/article/016/0002596973
#  https://n.news.naver.com/mnews/article/comment/016/0002596973
# 남양주서 친누나 살해한 30대 남성 긴급체포…어머니가 신고 https://n.news.naver.com/mnews/article/421/0008757735
#  https://n.news.naver.com/mnews/article/comment/421/0008757735

# %% [markdown]
# ### 2. Image 다운로드
# * referer 요청 헤더를 반드시 설정해야 한다.

# %%
import requests
import os

# 육아일기 73회차
req_header = {
    'referer':'https://comic.naver.com/webtoon/detail?titleId=812354&no=208&week=sun',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.3'
}

img_urls = [
    'https://image-comic.pstatic.net/webtoon/812354/208/20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_1.jpg',
    'https://image-comic.pstatic.net/webtoon/812354/208/20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_2.jpg',
    'https://image-comic.pstatic.net/webtoon/812354/208/20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_3.jpg'
]

for img_url in img_urls:
    # requests 의 get(url, headers) 함수 호출하기 
    res = requests.get(img_url, headers=req_header)
    print(res.status_code)
        
    # binary 응답 데이터 가져오기
    img_data = res.content    
    
    # url에서 파일명만 추출하기
    file_name = os.path.basename(img_url)
    print(file_name)

    # binday data를 file에 write하기
    with open(file_name,'wb') as file:
        print(f'Writing to {file_name}({len(img_data):,} bytes)')
        file.write(img_data)
# Out:
# 200
# 20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_1.jpg
# Writing to 20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_1.jpg(124,462 bytes)
# 200
# 20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_2.jpg
# Writing to 20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_2.jpg(141,956 bytes)
# 200
# 20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_3.jpg
# Writing to 20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_3.jpg(170,913 bytes)

# %% [markdown]
# * 현재 요청된 페이지의 image 모두 다운로드 해보기

# %%
import requests
from bs4 import BeautifulSoup
import os

webtoon_url = 'https://comic.naver.com/webtoon/detail?titleId=812354&no=208&week=thu'

req_header = {
    'referer':webtoon_url,
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.3'
}

res = requests.get(webtoon_url, headers=req_header)
if res.ok:
    # .jpg 파일명을 추출해서 list에 저장하기
    img_url_list = [] #list()
    soup = BeautifulSoup(res.text, 'html.parser')
    print(len(soup.select("img[src*='IMAG01']")))
    img_tags = soup.select("img[src*='IMAG01']")

    # for img_tag in img_tags:
    #     img_url = img_tag['src']
    #     img_url_list.append(img_url)

    # List Comprehension 
    img_url_list = [img_tag['src'] for img_tag in img_tags]
    print(img_url_list[:2])

    imgdir_name = 'img'
    if not os.path.isdir(imgdir_name):
        os.mkdir(imgdir_name)
    
    for img_url in img_url_list:
        res = requests.get(img_url, headers=req_header)
        img_data = res.content    
        file_path = os.path.join(imgdir_name, os.path.basename(img_url))

        with open(file_path,'wb') as file:
            print(f'Writing to {file_path}({len(img_data):,} bytes)')
            file.write(img_data)

else:
    print(f'Error Code = {res.status_code}')
# Out:
# 13
# ['https://image-comic.pstatic.net/webtoon/812354/208/20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_1.jpg', 'https://image-comic.pstatic.net/webtoon/812354/208/20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_2.jpg']
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_1.jpg(124,462 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_2.jpg(141,956 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_3.jpg(170,913 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_4.jpg(164,871 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_5.jpg(132,142 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_6.jpg(131,414 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_7.jpg(116,752 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_8.jpg(143,277 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_9.jpg(130,356 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_10.jpg(129,764 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_11.jpg(111,785 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_12.jpg(86,540 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_13.jpg(7,315 bytes)

# %% [markdown]
# ### 3. 파일 업로드 하기
# * http://httpbin.org/post 업로드 요청을 할 수 있는 url

# %%
import requests

upload_files = {
    
}
#print(upload_files)

url = 'http://httpbin.org/post'
# file 업로드 하려면 requests의 post 함수에 files 속성을 사용합니다.
# Out:
# 200

# %% [markdown]
# ### 4. 캡챠(이미지) API 호출하기
# * urllib 사용
# * 1. 캡차 키 발급 요청
#   2. 캡차 이미지 요청
#   3. 사용자 입력값 검증 요청

# %%
# 캡차 키 발급 요청

# %%
# 캡차 이미지 요청

# %%
#  사용자 입력값 검증 요청

# %% [markdown]
# * requests를 사용하는 코드로 변경하기
# * [requests docs](https://requests.readthedocs.io/en/latest/user/quickstart/)

# %%
# 사용자 입력값 검증 요청
# Out:
# Error Code: 403

# %% [markdown]
# ### 5. 블로그 검색하기

# %%
import requests
import pprint

headers = {
    'X-Naver-Client-Id': '',
    'X-Naver-Client-Secret': '',
}

payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'sim'
}

url = 'https://openapi.naver.com/v1/search/blog.json'


# requests get(url, params, headers) 요청 

# json() 함수로 응답 결과 가져오오기
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'

# 'data/nhnblog.txt' 파일 생성하기
